# %% [markdown]
# <a href="https://colab.research.google.com/github/dinithii/DL_lab01/blob/main/SE4050__Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

array_4x4 = np.random.exponential(scale=1.0, size=(4,4))

print("4x4 Exponential Distribution Array:")
print(array_4x4)
# Out:
# 4x4 Exponential Distribution Array:
# [[1.23706508 4.00637072 0.52373436 0.19139434]
#  [2.19377894 0.66541426 0.20701635 2.80955863]
#  [1.83786775 0.43853649 3.81817904 0.22851563]
#  [2.93385647 0.51613543 0.22417107 0.32777783]]

# %%
#100,000 samples from different distributions
exponential_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.uniform(low=0, high=4, size=100000)  # Adjusted range
normal_data = np.random.normal(loc=1, scale=0.8, size=100000)  # Adjusted parameters

# histogram comparison
plt.figure(figsize=(10, 6))
plt.hist(exponential_data, density=True, bins=50, histtype="step",
         color="red", label="Exponential", alpha=0.8)
plt.hist(uniform_data, density=True, bins=50, histtype="step",
         color="blue", label="Uniform", alpha=0.8)
plt.hist(normal_data, density=True, bins=50, histtype="step",
         color="green", label="Normal", alpha=0.8)

plt.axis([0, 6, 0, 1.2])
plt.legend(loc="upper right")
plt.title("Comparison of Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True, alpha=0.3)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')

ax.set_title("Z = X² + Y²")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

plt.show()

# %%
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# Select features
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
data = df[features]

# Calculate correlations
pearson_corr = data.corr(method='pearson')
spearman_corr = data.corr(method='spearman')

# Plot heatmaps
plt.figure(figsize=(14, 6))

# Pearson
plt.subplot(1, 2, 1)
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Pearson Correlation")

# Spearman
plt.subplot(1, 2, 2)
sns.heatmap(spearman_corr, annot=True, cmap='YlGnBu', fmt=".2f")
plt.title("Spearman Correlation")

plt.tight_layout()
plt.show()
