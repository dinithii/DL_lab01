# %% [markdown]
# <a href="https://colab.research.google.com/github/dinithii/DL_lab01/blob/main/task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://elitedatascience.com/python-seaborn-tutorial#step-10

# %%
import seaborn as sns
import matplotlib.pyplot as plt

features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
data = df[features]

pearson_corr = data.corr(method='pearson')
spearman_corr = data.corr(method='spearman')

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm')
plt.title("Pearson Correlation")

plt.subplot(1, 2, 2)
sns.heatmap(spearman_corr, annot=True, cmap='YlGnBu')
plt.title("Spearman Correlation")

plt.tight_layout()
plt.show()
